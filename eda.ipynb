# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, log_loss
from sklearn.calibration import calibration_curve, CalibratedClassifierCV


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Первичное ознакомление с данными

# %%
data_main = pd.read_csv('datasets/ufc-master.csv')
data_main.head()
# Out:
#           RedFighter        BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Alexandre Pantoja        Kai Asakura   -250.0     215.0           40.0000
# 1  Shavkat Rakhmonov  Ian Machado Garry   -210.0     295.0           47.6190
# 2         Ciryl Gane   Alexander Volkov   -380.0     300.0           26.3158
# 3     Bryce Mitchell        Kron Gracie   -950.0     625.0           10.5263
# 4      Nate Landwehr         Dooho Choi   -130.0     110.0           76.9231
#
#    BlueExpectedValue        Date                Location Country Winner  ...  \
# 0              215.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 1              295.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 2              300.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 3              625.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
# 4              110.0  2024-12-07  Las Vegas, Nevada, USA     USA   Blue  ...
#
#       FinishDetails FinishRound FinishRoundTime  TotalFightTimeSecs  \
# 0  Rear Naked Choke         2.0            2:05               425.0
# 1               NaN         5.0            5:00              1500.0
# 2               NaN         3.0            5:00               900.0
# 3            Elbows         3.0            0:39               639.0
# 4            Elbows         3.0            3:21               801.0
#
#    RedDecOdds  BlueDecOdds  RSubOdds  BSubOdds  RKOOdds  BKOOdds
# 0       300.0        800.0     150.0    2500.0    400.0    350.0
# 1       250.0        650.0     180.0    3000.0    240.0    700.0
# 2      -160.0        450.0    1100.0    3000.0    350.0   1100.0
# 3      -200.0       1100.0     380.0    1400.0    500.0   4000.0
# 4       275.0        550.0     500.0     700.0    300.0    250.0
#
# [5 rows x 118 columns]

# %%
print(data_main.shape)
# Out:
# (6528, 118)

# %%
print(*data_main.columns.to_list())
# Out:
# RedFighter BlueFighter RedOdds BlueOdds RedExpectedValue BlueExpectedValue Date Location Country Winner TitleBout WeightClass Gender NumberOfRounds BlueCurrentLoseStreak BlueCurrentWinStreak BlueDraws BlueAvgSigStrLanded BlueAvgSigStrPct BlueAvgSubAtt BlueAvgTDLanded BlueAvgTDPct BlueLongestWinStreak BlueLosses BlueTotalRoundsFought BlueTotalTitleBouts BlueWinsByDecisionMajority BlueWinsByDecisionSplit BlueWinsByDecisionUnanimous BlueWinsByKO BlueWinsBySubmission BlueWinsByTKODoctorStoppage BlueWins BlueStance BlueHeightCms BlueReachCms BlueWeightLbs RedCurrentLoseStreak RedCurrentWinStreak RedDraws RedAvgSigStrLanded RedAvgSigStrPct RedAvgSubAtt RedAvgTDLanded RedAvgTDPct RedLongestWinStreak RedLosses RedTotalRoundsFought RedTotalTitleBouts RedWinsByDecisionMajority RedWinsByDecisionSplit RedWinsByDecisionUnanimous RedWinsByKO RedWinsBySubmission RedWinsByTKODoctorStoppage RedWins RedStance RedHeightCms RedReachCms RedWeightLbs RedAge BlueAge LoseStreakDif WinStreakDif LongestWinStreakDif WinDif LossDif TotalRoundDif TotalTitleBoutDif KODif SubDif HeightDif ReachDif AgeDif SigStrDif AvgSubAttDif AvgTDDif EmptyArena BMatchWCRank RMatchWCRank RWFlyweightRank RWFeatherweightRank RWStrawweightRank RWBantamweightRank RHeavyweightRank RLightHeavyweightRank RMiddleweightRank RWelterweightRank RLightweightRank RFeatherweightRank RBantamweightRank RFlyweightRank RPFPRank BWFlyweightRank BWFeatherweightRank BWStrawweightRank BWBantamweightRank BHeavyweightRank BLightHeavyweightRank BMiddleweightRank BWelterweightRank BLightweightRank BFeatherweightRank BBantamweightRank BFlyweightRank BPFPRank BetterRank Finish FinishDetails FinishRound FinishRoundTime TotalFightTimeSecs RedDecOdds BlueDecOdds RSubOdds BSubOdds RKOOdds BKOOdds

# %% [markdown]
# Сразу отберем только те признаки, которые:
#  - кажутся наиболее значимыми для прогноза на основании личной экспертизы\
#  - имеются в доступе для формирования запросов на прогноз

# %%
valuable_features = ['RedFighter',
                     'BlueFighter',                  
                     'WeightClass',
                     'Gender',
                     'Winner',
                     'Finish',
                     'NumberOfRounds',
                     'RedAge',
                     'RedHeightCms',
                     'RedReachCms',
                     'RedWeightLbs',
                     'RedStance',
                     'RedWins',
                     'RedWinsByDecisionMajority',
                     'RedWinsByDecisionSplit',
                     'RedWinsByDecisionUnanimous',
                     'RedWinsByKO',
                     'RedWinsByTKODoctorStoppage',
                     'RedWinsBySubmission',
                     'RedCurrentWinStreak',
                     'RedLosses',
                     'RedCurrentLoseStreak',
                     'RedAvgSigStrLanded',
                     'RedAvgSigStrPct',                     
                     'RedAvgSubAtt',
                     'RedAvgTDLanded',
                     'RedAvgTDPct',
                     'RedTotalRoundsFought',
                     'BlueAge',
                     'BlueHeightCms',
                     'BlueReachCms',
                     'BlueWeightLbs',
                     'BlueStance',
                     'BlueWins',
                     'BlueWinsByDecisionMajority',
                     'BlueWinsByDecisionSplit',
                     'BlueWinsByDecisionUnanimous',
                     'BlueWinsByKO',
                     'BlueWinsByTKODoctorStoppage',
                     'BlueWinsBySubmission',
                     'BlueCurrentWinStreak',
                     'BlueLosses', 
                     'BlueCurrentLoseStreak',                    
                     'BlueAvgSigStrLanded',                 # Среднее количество значимых ударов, выбрасываемых в минуту синим бойцом
                     'BlueAvgSigStrPct',                    # Соотношение значимых попаданий к общему количеству значимых ударов для синего бойца   
                     'BlueAvgSubAtt',                       # Среднее количесвто попыток болевого приема за 15 минут для синего бойца
                     'BlueAvgTDLanded',                     # Среднее количесвто тейкдаунов за 15 минут для синего бойца
                     'BlueAvgTDPct',                        # Соотношение успешных тейкдаунов к общему количеству попыток для синего бойца
                     'BlueTotalRoundsFought'
                    ]

data = data_main[valuable_features]
# data = data_main

# %% [markdown]
# Преобразуем некоторые признаки

# %% [markdown]
# Напишем функцию, которая будет объединять признаки `Winner` и `Finish` в один признак `Result`, который будет принимать одно из шести возможных значений

# %%
def def_target(row):
    if row['Winner'] == 'Red':
        if row['Finish'] == 'KO/TKO':
            return 'Red-KO/TKO'
        elif row['Finish'] == 'SUB':
            return 'Red-Submission'
        else:
            return 'Red-Decision'
    if row['Winner'] == 'Blue':
        if row['Finish'] == 'KO/TKO':
            return 'Blue-KO/TKO'
        elif row['Finish'] == 'SUB':
            return 'Blue-Submission'
        else:
            return 'Blue-Decision'
        
data['Result'] = data.apply(def_target, axis=1)

# %% [markdown]
# Также объединим несколько признаков между собой для того, чтобы уменьшить количество признаков

# %%
data['RedWinsByDecision'] = data['RedWinsByDecisionMajority'] + data['RedWinsByDecisionSplit'] + data['RedWinsByDecisionUnanimous']
data['RedWinsByKO/TKO'] = data['RedWinsByKO'] + data['RedWinsByTKODoctorStoppage']

data['BlueWinsByDecision'] = data['BlueWinsByDecisionMajority'] + data['BlueWinsByDecisionSplit'] + data['BlueWinsByDecisionUnanimous']
data['BlueWinsByKO/TKO'] = data['BlueWinsByKO'] + data['BlueWinsByTKODoctorStoppage']

# Удалим лишние признаки
columns_to_drop = ['RedWinsByDecisionMajority',
                          'RedWinsByDecisionSplit',
                          'RedWinsByDecisionUnanimous',
                          'RedWinsByKO',
                          'RedWinsByTKODoctorStoppage',
                          'BlueWinsByDecisionMajority',
                          'BlueWinsByDecisionSplit',
                          'BlueWinsByDecisionUnanimous',
                          'BlueWinsByKO',
                          'BlueWinsByTKODoctorStoppage',
                          'Winner',
                          'Finish'
                        #   'RedWeightLbs',
                        #   'BlueWeightLbs'                          
                    ]

data = data.drop(columns=columns_to_drop, axis=1)

# %% [markdown]
# ### Работа с признаками

# %% [markdown]
# Бинарные и ориднильные признаки можно преобразовать в числовой вид

# %%
binary_features = ['Gender', 'NumberOfRounds', 'RedStance', 'BlueStance']
data['Gender'] = data['Gender'].map({'FEMALE': 0, 'MALE': 1})
data['NumberOfRounds'] = data['NumberOfRounds'].map({3: 0, 5: 1})
data['RedStance'] = data['RedStance'].map({'Southpaw': 0, 'Orthodox': 1})
data['BlueStance'] = data['BlueStance'].map({'Southpaw': 0, 'Orthodox': 1})

ordinal_features = ['WeightClass', 'Result']
data['WeightClass'] = data['WeightClass'].map({"Women's Strawweight": 0,
                                               'Flyweight': 0,
                                               "Women's Flyweight": 0,
                                               'Bantamweight': 1,
                                               "Women's Bantamweight": 1,
                                               'Featherweight': 2,
                                               "Women's Featherweight": 2,
                                               'Catch Weight': 2,
                                               'Lightweight': 3,
                                               'Welterweight': 4,
                                               'Middleweight': 5,
                                               'Light Heavyweight': 6,
                                               'Heavyweight': 7})

data['Result'] = data['Result'].map({'Red-KO/TKO': 0,
                                     'Red-Submission': 1,
                                     'Red-Decision': 2,
                                     'Blue-KO/TKO': 3,
                                     'Blue-Submission' : 4,
                                     'Blue-Decision': 5                                     
                                    })

# %%
data
# Out:
#              RedFighter        BlueFighter  WeightClass  Gender  \
# 0     Alexandre Pantoja        Kai Asakura            0       1
# 1     Shavkat Rakhmonov  Ian Machado Garry            4       1
# 2            Ciryl Gane   Alexander Volkov            7       1
# 3        Bryce Mitchell        Kron Gracie            2       1
# 4         Nate Landwehr         Dooho Choi            2       1
# ...                 ...                ...          ...     ...
# 6523       Duane Ludwig      Darren Elkins            3       1
# 6524        John Howard     Daniel Roberts            4       1
# 6525     Brendan Schaub      Chase Gormley            7       1
# 6526        Mike Pierce      Julio Paulino            4       1
# 6527       Eric Schafer        Jason Brilz            6       1
#
#       NumberOfRounds  RedAge  RedHeightCms  RedReachCms  RedWeightLbs  \
# 0                1.0      34        165.10       170.18           125
# 1                0.0      30        185.42       195.58           170
# 2                0.0      34        193.04       205.74           245
# 3                0.0      30        177.80       177.80           145
# 4                0.0      36        175.26       182.88           145
# ...              ...     ...           ...          ...           ...
# 6523             0.0      31        177.80       177.80           170
# 6524             0.0      27        170.18       180.34           170
# 6525             0.0      27        193.04       198.12           245
# 6526             0.0      29        172.72       177.80           170
# 6527             0.0      32        190.50       190.50           185
#
#       RedStance  ...  BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  \
# 0           1.0  ...              0.00         0.0000           0.0000
# 1           1.0  ...              0.55         0.3000           0.7700
# 2           1.0  ...              0.57         0.2000           0.4500
# 3           0.0  ...              0.44         0.5000           0.4700
# 4           1.0  ...              0.53         0.8000           0.7500
# ...         ...  ...               ...            ...              ...
# 6523        1.0  ...               NaN            NaN              NaN
# 6524        1.0  ...               NaN            NaN              NaN
# 6525        1.0  ...              0.34         1.0000           1.0000
# 6526        1.0  ...               NaN            NaN              NaN
# 6527        1.0  ...              0.46         0.6667           1.6667
#
#       BlueAvgTDPct  BlueTotalRoundsFought  Result  RedWinsByDecision  \
# 0             0.00                      0       1                  6
# 1             0.55                     20       2                  0
# 2             0.63                     44       2                  3
# 3             0.25                      7       0                  6
# 4             0.37                     15       3                  2
# ...            ...                    ...     ...                ...
# 6523           NaN                      0       3                  1
# 6524           NaN                      0       0                  2
# 6525          1.00                      1       0                  0
# 6526           NaN                      0       2                  1
# 6527          0.50                      8       5                  0
#
#       RedWinsByKO/TKO  BlueWinsByDecision  BlueWinsByKO/TKO
# 0                   2                   0                 0
# 1                   1                   5                 3
# 2                   4                   5                 6
# 3                   0                   0                 0
# 4                   1                   0                 4
# ...               ...                 ...               ...
# 6523                1                   0                 0
# 6524                1                   0                 0
# 6525                0                   0                 0
# 6526                0                   0                 0
# 6527                1                   1                 1
#
# [6528 rows x 42 columns]

# %% [markdown]
# Заполнение пропусков

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6528 entries, 0 to 6527
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RedFighter             6528 non-null   object
#  1   BlueFighter            6528 non-null   object
#  2   WeightClass            6528 non-null   int64
#  3   Gender                 6528 non-null   int64
#  4   NumberOfRounds         6507 non-null   float64
#  5   RedAge                 6528 non-null   int64
#  6   RedHeightCms           6528 non-null   float64
#  7   RedReachCms            6528 non-null   float64
#  8   RedWeightLbs           6528 non-null   int64
#  9   RedStance              6153 non-null   float64
#  10  RedWins                6528 non-null   int64
#  11  RedWinsBySubmission    6528 non-null   int64
#  12  RedCurrentWinStreak    6528 non-null   int64
#  13  RedLosses              6528 non-null   int64
#  14  RedCurrentLoseStreak   6528 non-null   int64
#  15  RedAvgSigStrLanded     6073 non-null   float64
#  16  RedAvgSigStrPct        6171 non-null   float64
#  17  RedAvgSubAtt           6171 non-null   float64
#  18  RedAvgTDLanded         6171 non-null   float64
#  19  RedAvgTDPct            6161 non-null   float64
#  20  RedTotalRoundsFought   6528 non-null   int64
#  21  BlueAge                6528 non-null   int64
#  22  BlueHeightCms          6528 non-null   float64
#  23  BlueReachCms           6528 non-null   float64
#  24  BlueWeightLbs          6528 non-null   int64
#  25  BlueStance             6118 non-null   float64
#  26  BlueWins               6528 non-null   int64
#  27  BlueWinsBySubmission   6528 non-null   int64
#  28  BlueCurrentWinStreak   6528 non-null   int64
#  29  BlueLosses             6528 non-null   int64
#  30  BlueCurrentLoseStreak  6528 non-null   int64
#  31  BlueAvgSigStrLanded    5598 non-null   float64
#  32  BlueAvgSigStrPct       5763 non-null   float64
#  33  BlueAvgSubAtt          5696 non-null   float64
#  34  BlueAvgTDLanded        5695 non-null   float64
#  35  BlueAvgTDPct           5686 non-null   float64
#  36  BlueTotalRoundsFought  6528 non-null   int64
#  37  Result                 6528 non-null   int64
#  38  RedWinsByDecision      6528 non-null   int64
#  39  RedWinsByKO/TKO        6528 non-null   int64
#  40  BlueWinsByDecision     6528 non-null   int64
#  41  BlueWinsByKO/TKO       6528 non-null   int64
# dtypes: float64(17), int64(23), object(2)
# memory usage: 2.1+ MB

# %%
for col in data.columns:
    isna_sum = 0
    if data[col].isna().any():
        isna_sum = data[col].isna().sum()
        print(f'{col}: {isna_sum}')
# Out:
# NumberOfRounds: 21
# RedStance: 375
# RedAvgSigStrLanded: 455
# RedAvgSigStrPct: 357
# RedAvgSubAtt: 357
# RedAvgTDLanded: 357
# RedAvgTDPct: 367
# BlueStance: 410
# BlueAvgSigStrLanded: 930
# BlueAvgSigStrPct: 765
# BlueAvgSubAtt: 832
# BlueAvgTDLanded: 833
# BlueAvgTDPct: 842

# %%
data['NumberOfRounds'] = data['NumberOfRounds'].fillna(0)
data['RedStance'] = data['RedStance'].fillna(1)
data['BlueStance'] = data['BlueStance'].fillna(1)

# %%
colmns_with_nans = ['RedAvgSigStrLanded',
                    'RedAvgSigStrPct',
                    'RedAvgSubAtt',
                    'RedAvgTDLanded',
                    'RedAvgTDPct',
                    'BlueAvgSigStrLanded',
                    'BlueAvgSigStrPct',
                    'BlueAvgSubAtt',
                    'BlueAvgTDLanded',
                    'BlueAvgTDPct'
                    ]

df_fillna_vals = data.groupby(by='WeightClass')[colmns_with_nans].mean().reset_index()
for col in colmns_with_nans:
    for i in range(8):
        data.loc[(data['WeightClass'] == i) & (data[col].isna()), col] = df_fillna_vals.loc[i, col]

# %%
for col in data.columns:
    isna_sum = 0
    if data[col].isna().any():
        isna_sum = data[col].isna().sum()
        print(f'{col}: {isna_sum}')

# %%
data
# Out:
#              RedFighter        BlueFighter  WeightClass  Gender  \
# 0     Alexandre Pantoja        Kai Asakura            0       1
# 1     Shavkat Rakhmonov  Ian Machado Garry            4       1
# 2            Ciryl Gane   Alexander Volkov            7       1
# 3        Bryce Mitchell        Kron Gracie            2       1
# 4         Nate Landwehr         Dooho Choi            2       1
# ...                 ...                ...          ...     ...
# 6523       Duane Ludwig      Darren Elkins            3       1
# 6524        John Howard     Daniel Roberts            4       1
# 6525     Brendan Schaub      Chase Gormley            7       1
# 6526        Mike Pierce      Julio Paulino            4       1
# 6527       Eric Schafer        Jason Brilz            6       1
#
#       NumberOfRounds  RedAge  RedHeightCms  RedReachCms  RedWeightLbs  \
# 0                1.0      34        165.10       170.18           125
# 1                0.0      30        185.42       195.58           170
# 2                0.0      34        193.04       205.74           245
# 3                0.0      30        177.80       177.80           145
# 4                0.0      36        175.26       182.88           145
# ...              ...     ...           ...          ...           ...
# 6523             0.0      31        177.80       177.80           170
# 6524             0.0      27        170.18       180.34           170
# 6525             0.0      27        193.04       198.12           245
# 6526             0.0      29        172.72       177.80           170
# 6527             0.0      32        190.50       190.50           185
#
#       RedStance  ...  BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  \
# 0           1.0  ...          0.000000       0.000000         0.000000
# 1           1.0  ...          0.550000       0.300000         0.770000
# 2           1.0  ...          0.570000       0.200000         0.450000
# 3           0.0  ...          0.440000       0.500000         0.470000
# 4           1.0  ...          0.530000       0.800000         0.750000
# ...         ...  ...               ...            ...              ...
# 6523        1.0  ...          0.432868       0.493944         1.407819
# 6524        1.0  ...          0.453011       0.500342         1.311283
# 6525        1.0  ...          0.340000       1.000000         1.000000
# 6526        1.0  ...          0.453011       0.500342         1.311283
# 6527        1.0  ...          0.460000       0.666700         1.666700
#
#       BlueAvgTDPct  BlueTotalRoundsFought  Result  RedWinsByDecision  \
# 0         0.000000                      0       1                  6
# 1         0.550000                     20       2                  0
# 2         0.630000                     44       2                  3
# 3         0.250000                      7       0                  6
# 4         0.370000                     15       3                  2
# ...            ...                    ...     ...                ...
# 6523      0.316449                      0       3                  1
# 6524      0.329691                      0       0                  2
# 6525      1.000000                      1       0                  0
# 6526      0.329691                      0       2                  1
# 6527      0.500000                      8       5                  0
#
#       RedWinsByKO/TKO  BlueWinsByDecision  BlueWinsByKO/TKO
# 0                   2                   0                 0
# 1                   1                   5                 3
# 2                   4                   5                 6
# 3                   0                   0                 0
# 4                   1                   0                 4
# ...               ...                 ...               ...
# 6523                1                   0                 0
# 6524                1                   0                 0
# 6525                0                   0                 0
# 6526                0                   0                 0
# 6527                1                   1                 1
#
# [6528 rows x 42 columns]

# %% [markdown]
# От пропусков в данных избавились. Теперь посмотрим на наличие выбросов

# %%
data.describe()
# Out:
#        WeightClass       Gender  NumberOfRounds       RedAge  RedHeightCms  \
# count  6528.000000  6528.000000     6528.000000  6528.000000   6528.000000
# mean      3.109528     0.877298        0.091146    30.359528    177.802399
# std       2.113114     0.328120        0.287838     4.180712      9.182963
# min       0.000000     0.000000        0.000000    18.000000    152.400000
# 25%       1.000000     1.000000        0.000000    27.000000    170.180000
# 50%       3.000000     1.000000        0.000000    30.000000    177.800000
# 75%       5.000000     1.000000        0.000000    33.000000    185.420000
# max       7.000000     1.000000        1.000000    47.000000    210.820000
#
#        RedReachCms  RedWeightLbs    RedStance      RedWins  \
# count  6528.000000   6528.000000  6528.000000  6528.000000
# mean    182.410954    163.621324     0.804534     4.628064
# std      11.130395     34.846543     0.396589     4.505498
# min     147.320000    115.000000     0.000000     0.000000
# 25%     175.260000    135.000000     1.000000     1.000000
# 50%     182.880000    155.000000     1.000000     3.000000
# 75%     190.500000    185.000000     1.000000     7.000000
# max     214.630000    265.000000     1.000000    33.000000
#
#        RedWinsBySubmission  ...  BlueAvgSigStrPct  BlueAvgSubAtt  \
# count          6528.000000  ...       6528.000000    6528.000000
# mean              0.934589  ...          0.452981       0.499980
# std               1.608402  ...          0.104272       0.629118
# min               0.000000  ...          0.000000       0.000000
# 25%               0.000000  ...          0.410000       0.000000
# 50%               0.000000  ...          0.453011       0.375000
# 75%               1.000000  ...          0.503000       0.666700
# max              16.000000  ...          1.000000       8.400000
#
#        BlueAvgTDLanded  BlueAvgTDPct  BlueTotalRoundsFought       Result  \
# count      6528.000000   6528.000000            6528.000000  6528.000000
# mean          1.320765      0.325271              11.872396     2.466912
# std           1.267825      0.223308              13.845139     1.713636
# min           0.000000      0.000000               0.000000     0.000000
# 25%           0.420000      0.190000               3.000000     1.000000
# 50%           1.120000      0.329552               7.000000     2.000000
# 75%           1.750000      0.441250              17.000000     4.000000
# max          10.860000      1.000000             111.000000     5.000000
#
#        RedWinsByDecision  RedWinsByKO/TKO  BlueWinsByDecision  \
# count        6528.000000      6528.000000         6528.000000
# mean            2.040135         1.599418            1.391238
# std             2.347003         2.190606            1.915592
# min             0.000000         0.000000            0.000000
# 25%             0.000000         0.000000            0.000000
# 50%             1.000000         1.000000            1.000000
# 75%             3.000000         2.000000            2.000000
# max            14.000000        21.000000           13.000000
#
#        BlueWinsByKO/TKO
# count       6528.000000
# mean           1.088542
# std            1.751570
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            2.000000
# max           20.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# Построим boxplot для признаков со статистическими данными бойцов

# %%
stats_columns = ['RedAvgSigStrLanded',
                'BlueAvgSigStrLanded',
                'RedAvgSigStrPct',
                'BlueAvgSigStrPct',
                'RedAvgSubAtt',
                'BlueAvgSubAtt',
                'RedAvgTDLanded',
                'BlueAvgTDLanded',
                'RedAvgTDPct',
                'BlueAvgTDPct'
                ]             
                  
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(14, 14))
for i in range(len(stats_columns)):
    axs[int(i // 4), i % 4].boxplot(data[stats_columns[i]])
    axs[int(i // 4), i % 4].set_title(stats_columns[i])

# %%
fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(12, 19))
for i in range(len(stats_columns)):
    axs[int(i // 2), i % 2].hist(data[stats_columns[i]], bins=30)
    axs[int(i // 2), i % 2].set_title(stats_columns[i])
    axs[int(i // 2), i % 2].grid()

# %% [markdown]
# Посмотрим на признаки более пристально. Похоже что они содержат аномальные значения

# %%
data[stats_columns].describe()
# Out:
#        RedAvgSigStrLanded  BlueAvgSigStrLanded  RedAvgSigStrPct  \
# count         6528.000000          6528.000000      6528.000000
# mean            21.163432            19.855928         0.460205
# std             19.182438            18.822988         0.095679
# min              0.000000             0.000000         0.000000
# 25%              4.320000             4.220000         0.410000
# 50%             19.000000            17.713136         0.460000
# 75%             32.606250            29.333300         0.510000
# max            141.000000           154.000000         1.000000
#
#        BlueAvgSigStrPct  RedAvgSubAtt  BlueAvgSubAtt  RedAvgTDLanded  \
# count       6528.000000   6528.000000    6528.000000     6528.000000
# mean           0.452981      0.537523       0.499980        1.400722
# std            0.104272      0.674123       0.629118        1.272464
# min            0.000000      0.000000       0.000000        0.000000
# 25%            0.410000      0.000000       0.000000        0.500000
# 50%            0.453011      0.400000       0.375000        1.150000
# 75%            0.503000      0.777800       0.666700        2.000000
# max            1.000000      8.400000       8.400000       12.500000
#
#        BlueAvgTDLanded  RedAvgTDPct  BlueAvgTDPct
# count      6528.000000  6528.000000   6528.000000
# mean          1.320765     0.341521      0.325271
# std           1.267825     0.214729      0.223308
# min           0.000000     0.000000      0.000000
# 25%           0.420000     0.210000      0.190000
# 50%           1.120000     0.340000      0.329552
# 75%           1.750000     0.460000      0.441250
# max          10.860000     1.000000      1.000000

# %% [markdown]
# Возьмем одного бойца и посмотрим признаки, описывающие его статистики

# %%
data[data['BlueFighter'] == 'Yan Xiaonan'][['BlueFighter'] + stats_columns[1::2]]
# Out:
#       BlueFighter  BlueAvgSigStrLanded  BlueAvgSigStrPct  BlueAvgSubAtt  \
# 341   Yan Xiaonan             4.970000          0.440000       0.000000
# 827   Yan Xiaonan             4.970000          0.440000       0.000000
# 1112  Yan Xiaonan             4.970000          0.440000       0.000000
# 1432  Yan Xiaonan             4.970000          0.440000       0.000000
# 2067  Yan Xiaonan             6.720000          0.420000       0.000000
# 2397  Yan Xiaonan             6.850000          0.400000       0.000000
# 3230  Yan Xiaonan            96.000000          0.450000       0.000000
# 3494  Yan Xiaonan            17.797391          0.443653       0.568189
#
#       BlueAvgTDLanded  BlueAvgTDPct
# 341          1.000000      0.730000
# 827          1.000000      0.730000
# 1112         1.000000      0.730000
# 1432         1.000000      0.730000
# 2067         1.200000      0.750000
# 2397         0.250000      0.250000
# 3230         0.000000      0.000000
# 3494         1.370605      0.362627

# %%
data.groupby(by='RedFighter')[stats_columns[0::2]].median().reset_index()
# Out:
#               RedFighter  RedAvgSigStrLanded  RedAvgSigStrPct  RedAvgSubAtt  \
# 0          Jun Yong Park           19.501712            0.522           0.0
# 1              AJ Dobson            4.290000            0.460           0.3
# 2            AJ Fletcher            3.360000            0.490           0.9
# 3             Aalon Cruz            9.040000            0.400           0.0
# 4         Aaron Phillips            9.755000            0.490           0.8
# ...                  ...                 ...              ...           ...
# 1656        Zhang Lipeng           14.500000            0.435           1.5
# 1657      Zhang Mingyang            8.900000            0.560           0.0
# 1658         Zhang Weili            5.660000            0.530           0.5
# 1659    Zubaira Tukhugov           35.000000            0.390           0.0
# 1660  Zygimantas Ramaska            0.960000            0.600           2.4
#
#       RedAvgTDLanded  RedAvgTDPct
# 0               0.50         0.25
# 1               1.67         0.75
# 2               1.54         0.35
# 3               0.00         0.00
# 4               0.43         0.25
# ...              ...          ...
# 1656            3.00         0.40
# 1657            0.00         0.00
# 1658            2.51         0.46
# 1659            2.13         0.39
# 1660            0.00         0.00
#
# [1661 rows x 6 columns]

# %%
data[data['RedFighter'] == 'Zubaira Tukhugov'][['RedFighter'] + stats_columns[0::2]]
# Out:
#             RedFighter  RedAvgSigStrLanded  RedAvgSigStrPct  RedAvgSubAtt  \
# 967   Zubaira Tukhugov                3.17            0.390           0.0
# 4399  Zubaira Tukhugov               37.50            0.475           0.0
# 4941  Zubaira Tukhugov               35.00            0.360           0.0
#
#       RedAvgTDLanded  RedAvgTDPct
# 967             2.13         0.39
# 4399            1.50         0.25
# 4941            3.00         0.50

# %% [markdown]
# Видно, что многие данные (особенно данные о более давнишних боях) содержат аномальные значения. Поскольку данные упорядочены во времени, можно попробовать определить границу, после которой начинают появляться аномальные значения

# %%
df_replace_outbursts = data.iloc[:1000, :].groupby(by='WeightClass')[stats_columns].median().reset_index()
df_replace_outbursts
# Out:
#    WeightClass  RedAvgSigStrLanded  BlueAvgSigStrLanded  RedAvgSigStrPct  \
# 0            0               4.100                3.880             0.46
# 1            1               4.165                4.165             0.47
# 2            2               4.210                3.880             0.48
# 3            3               4.390                4.375             0.48
# 4            4               4.110                4.250             0.48
# 5            5               4.120                4.000             0.50
# 6            6               3.855                3.800             0.50
# 7            7               3.770                3.940             0.49
#
#    BlueAvgSigStrPct  RedAvgSubAtt  BlueAvgSubAtt  RedAvgTDLanded  \
# 0             0.460          0.50           0.40           1.605
# 1             0.470          0.35           0.30           1.245
# 2             0.480          0.50           0.60           1.100
# 3             0.475          0.35           0.25           1.450
# 4             0.480          0.40           0.20           1.160
# 5             0.500          0.40           0.30           1.480
# 6             0.490          0.30           0.10           0.720
# 7             0.500          0.20           0.20           0.690
#
#    BlueAvgTDLanded  RedAvgTDPct  BlueAvgTDPct
# 0            1.185        0.395          0.35
# 1            1.145        0.365          0.33
# 2            1.100        0.400          0.35
# 3            1.315        0.360          0.36
# 4            1.020        0.390          0.35
# 5            1.200        0.380          0.41
# 6            0.580        0.330          0.33
# 7            0.710        0.330          0.38

# %%
df_replace_outbursts = data.iloc[:2500, :].groupby(by='WeightClass')[stats_columns].median().reset_index()
df_replace_outbursts
# Out:
#    WeightClass  RedAvgSigStrLanded  BlueAvgSigStrLanded  RedAvgSigStrPct  \
# 0            0                3.97                3.950             0.45
# 1            1                4.12                3.975             0.46
# 2            2                4.10                3.835             0.46
# 3            3                4.21                4.070             0.46
# 4            4                4.25                4.060             0.47
# 5            5                3.98                3.750             0.50
# 6            6                3.87                3.730             0.49
# 7            7                3.77                4.150             0.49
#
#    BlueAvgSigStrPct  RedAvgSubAtt  BlueAvgSubAtt  RedAvgTDLanded  \
# 0              0.46          0.50            0.3            1.45
# 1              0.46          0.30            0.3            1.07
# 2              0.46          0.50            0.4            1.18
# 3              0.47          0.40            0.2            1.45
# 4              0.47          0.40            0.2            1.16
# 5              0.49          0.30            0.3            1.48
# 6              0.49          0.20            0.1            0.63
# 7              0.49          0.15            0.1            0.58
#
#    BlueAvgTDLanded  RedAvgTDPct  BlueAvgTDPct
# 0            1.120     0.373573          0.36
# 1            1.080     0.370000          0.33
# 2            1.075     0.400000          0.35
# 3            1.190     0.360000          0.34
# 4            1.020     0.400000          0.36
# 5            1.220     0.390000          0.40
# 6            0.720     0.330000          0.33
# 7            0.550     0.330000          0.33

# %% [markdown]
# Примерно после 2500 тысяч строчек в данных начинается полный хаос, ликвидировать который нет никакой возможности. Поэтому оставим только первые 2500 тысячи строк. Пожертвуем данными ради качества.

# %% [markdown]
# ### Работа с уменьшенной выборкой

# %%
data_reduced = data_main.iloc[:1500, :]
# data_reduced = data_main

# %% [markdown]
# Таким образом видим, что оставшиеся данные охватывают период за последние 5 лет

# %%
# Уменьшаем количество используемых признаков
data = data_reduced[valuable_features]
# data = data_reduced

# Создаем новый столбец с целевой переменной
data.loc[:, 'Result'] = data.apply(def_target, axis=1)
# Обединяем 
data.loc[:, 'RedWinsByDecision'] = data['RedWinsByDecisionMajority'] + data['RedWinsByDecisionSplit'] + data['RedWinsByDecisionUnanimous']
data.loc[:, 'RedWinsByKO/TKO'] = data['RedWinsByKO'] + data['RedWinsByTKODoctorStoppage']

data.loc[:, 'BlueWinsByDecision'] = data['BlueWinsByDecisionMajority'] + data['BlueWinsByDecisionSplit'] + data['BlueWinsByDecisionUnanimous']
data.loc[:, 'BlueWinsByKO/TKO'] = data['BlueWinsByKO'] + data['BlueWinsByTKODoctorStoppage']

# Удалим лишние признаки
data = data.drop(columns=columns_to_drop, axis=1)

# %%
data['Result'].value_counts(normalize=True)
# Out:
# Result
# Red-Decision       0.278000
# Blue-Decision      0.221333
# Red-KO/TKO         0.179333
# Blue-KO/TKO        0.133333
# Red-Submission     0.109333
# Blue-Submission    0.078667
# Name: proportion, dtype: float64

# %%
# Преобразуем бинарные и ординальные признаки в числовой вид
binary_features = ['Gender', 'NumberOfRounds', 'RedStance', 'BlueStance']
data['Gender'] = data['Gender'].map({'FEMALE': 0, 'MALE': 1})
data['NumberOfRounds'] = data['NumberOfRounds'].map({3: 1, 5: 0})
data['RedStance'] = data['RedStance'].map({'Southpaw': 0, 'Orthodox': 1})
data['BlueStance'] = data['BlueStance'].map({'Southpaw': 0, 'Orthodox': 1})

ordinal_features = ['WeightClass', 'Result']
data['WeightClass'] = data['WeightClass'].map({"Women's Strawweight": 0,
                                               'Flyweight': 0,
                                               "Women's Flyweight": 0,
                                               'Bantamweight': 1,
                                               "Women's Bantamweight": 1,
                                               'Featherweight': 2,
                                               "Women's Featherweight": 2,
                                               'Catch Weight': 2,
                                               'Lightweight': 3,
                                               'Welterweight': 4,
                                               'Middleweight': 5,
                                               'Light Heavyweight': 6,
                                               'Heavyweight': 7})

data['Result'] = data['Result'].map({'Red-Decision': 0,
                                     'Blue-Decision': 1, 
                                     'Red-KO/TKO': 2,
                                     'Blue-KO/TKO': 3,
                                     'Red-Submission': 4,                                     
                                     'Blue-Submission' : 5                                                                         
                                    })

# %%
for col in data.columns:
    isna_sum = 0
    if data[col].isna().any():
        isna_sum = data[col].isna().sum()
        print(f'{col}: {isna_sum}')
# Out:
# RedStance: 173
# BlueStance: 159

# %%
data['RedStance'] = data['RedStance'].fillna(1)
data['BlueStance'] = data['BlueStance'].fillna(1)

colmns_with_nans = ['RedAvgSigStrLanded',                    
                    'RedAvgTDPct',
                    'BlueAvgSigStrLanded',
                    'BlueAvgTDLanded',
                    'BlueAvgTDPct'
                    ]

df_fillna_vals = data.groupby(by='WeightClass')[colmns_with_nans].mean().reset_index()
for col in colmns_with_nans:
    for i in range(8):
        data.loc[(data['WeightClass'] == i) & (data[col].isna()), col] = df_fillna_vals.loc[i, col]

# %%
ig, axs = plt.subplots(nrows=3, ncols=4, figsize=(14, 14))
for i in range(len(stats_columns)):
    axs[int(i // 4), i % 4].boxplot(data[stats_columns[i]])
    axs[int(i // 4), i % 4].set_title(stats_columns[i])

# %%
fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(12, 19))
for i in range(len(stats_columns)):
    axs[int(i // 2), i % 2].hist(data[stats_columns[i]], bins=30)
    axs[int(i // 2), i % 2].set_title(stats_columns[i])
    axs[int(i // 2), i % 2].grid()

# %% [markdown]
# Теперь посмотрим на наличие корреляций

# %%
data.head(2)
# Out:
#           RedFighter        BlueFighter  WeightClass  Gender  NumberOfRounds  \
# 0  Alexandre Pantoja        Kai Asakura            0       1               0
# 1  Shavkat Rakhmonov  Ian Machado Garry            4       1               1
#
#    RedAge  RedHeightCms  RedReachCms  RedWeightLbs  RedStance  ...  \
# 0      34        165.10       170.18           125        1.0  ...
# 1      30        185.42       195.58           170        1.0  ...
#
#    BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  BlueAvgTDPct  \
# 0              0.00            0.0             0.00          0.00
# 1              0.55            0.3             0.77          0.55
#
#    BlueTotalRoundsFought  Result  RedWinsByDecision  RedWinsByKO/TKO  \
# 0                      0       4                  6                2
# 1                     20       0                  0                1
#
#    BlueWinsByDecision  BlueWinsByKO/TKO
# 0                   0                 0
# 1                   5                 3
#
# [2 rows x 42 columns]

# %%
red_fighter_features = [col for col in data.columns if 'Red' in col]
# Добавим к рассмотрению целевую переменную
red_fighter_features.append('Result')
# Выберем из датасета только те бои, где победил красный боец
data_red = data[data['Result'].isin([0, 1, 2])]

corr_matrix = data_red[red_fighter_features[1:]].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        WeightClass       Gender  NumberOfRounds       RedAge  RedHeightCms  \
# count  1500.000000  1500.000000     1500.000000  1500.000000   1500.000000
# mean      2.764000     0.825333        0.902667    31.286667    177.168387
# std       2.190472     0.379808        0.296510     4.253848      9.584136
# min       0.000000     0.000000        0.000000    18.000000    152.400000
# 25%       1.000000     1.000000        1.000000    28.000000    170.180000
# 50%       3.000000     1.000000        1.000000    31.000000    177.800000
# 75%       4.250000     1.000000        1.000000    34.000000    185.420000
# max       7.000000     1.000000        1.000000    45.000000    200.660000
#
#        RedReachCms  RedWeightLbs    RedStance      RedWins  \
# count  1500.000000   1500.000000  1500.000000  1500.000000
# mean    181.880933    158.718667     0.827333     5.630000
# std      11.801122     34.880271     0.378085     4.994169
# min     147.320000    115.000000     0.000000     0.000000
# 25%     172.720000    135.000000     1.000000     2.000000
# 50%     180.340000    155.000000     1.000000     4.000000
# 75%     190.500000    170.000000     1.000000     8.000000
# max     213.360000    265.000000     1.000000    27.000000
#
#        RedWinsBySubmission  ...  BlueAvgSigStrPct  BlueAvgSubAtt  \
# count           1500.00000  ...       1500.000000    1500.000000
# mean               1.13800  ...          0.474753       0.489600
# std                1.88361  ...          0.074476       0.659754
# min                0.00000  ...          0.000000       0.000000
# 25%                0.00000  ...          0.430000       0.000000
# 50%                0.00000  ...          0.480000       0.300000
# 75%                2.00000  ...          0.520000       0.700000
# max               16.00000  ...          0.800000       8.400000
#
#        BlueAvgTDLanded  BlueAvgTDPct  BlueTotalRoundsFought       Result  \
# count      1500.000000   1500.000000            1500.000000  1500.000000
# mean          1.503820      0.357053              15.300667     1.810667
# std           1.401948      0.208873              15.510039     1.605575
# min           0.000000      0.000000               0.000000     0.000000
# 25%           0.500000      0.250000               4.000000     0.000000
# 50%           1.080000      0.360000              11.000000     2.000000
# 75%           2.140000      0.500000              21.000000     3.000000
# max           9.630000      1.000000             111.000000     5.000000
#
#        RedWinsByDecision  RedWinsByKO/TKO  BlueWinsByDecision  \
# count        1500.000000      1500.000000         1500.000000
# mean            2.578000         1.908667            1.819333
# std             2.761582         2.365034            2.200437
# min             0.000000         0.000000            0.000000
# 25%             1.000000         0.000000            0.000000
# 50%             2.000000         1.000000            1.000000
# 75%             4.000000         3.000000            3.000000
# max            14.000000        21.000000           13.000000
#
#        BlueWinsByKO/TKO
# count        1500.00000
# mean            1.38600
# std             1.77062
# min             0.00000
# 25%             0.00000
# 50%             1.00000
# 75%             2.00000
# max            14.00000
#
# [8 rows x 40 columns]

# %% [markdown]
# Посмотрим на распределение классов целевой переменной

# %%
data['Result'].value_counts(normalize='True')
# Out:
# Result
# 0    0.278000
# 1    0.221333
# 2    0.179333
# 3    0.133333
# 4    0.109333
# 5    0.078667
# Name: proportion, dtype: float64

# %% [markdown]
# ### Преобразование данных для обучения модели

# %%
X = data.drop(columns=['Result', 'RedFighter', 'BlueFighter'], axis=1)
y = data['Result']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=8)

test_size = int(len(X)*0.2)
X_train = X.iloc[test_size:, :]
y_train = y.iloc[test_size:]
X_test = X.iloc[:test_size, :]
y_test = y.iloc[:test_size]

# %%
pipeline = Pipeline([('imputer', SimpleImputer(strategy='median')),
                     ('scaler', MinMaxScaler()),
                     ('classifier', LogisticRegression(multi_class='multinomial', random_state=8))
                     ])

# Обучаем pipeline на тренировочных данных
pipeline.fit(X_train, y_train)

# Делаем прогнозы на тестовых данных
y_pred = pipeline.predict(X_test)

# Выводим метрики качества модели
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Матрица ошибок
print("Confusion Matrix:")
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix,  annot=True, fmt='d', cmap='YlGnBu')
plt.ylabel('Real value')
plt.xlabel('predicted value')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.58      0.50        92
#            1       0.43      0.38      0.40        80
#            2       0.39      0.52      0.45        44
#            3       0.20      0.12      0.15        32
#            4       0.33      0.28      0.30        29
#            5       0.29      0.09      0.13        23
#
#     accuracy                           0.40       300
#    macro avg       0.35      0.33      0.32       300
# weighted avg       0.38      0.40      0.38       300
#
# Confusion Matrix:
# Text(0.5, 23.52222222222222, 'predicted value')

# %% [markdown]
# ### Упростим задачу. Бинарная классификация

# %%
from copy import deepcopy

data_binary = deepcopy(data)
data_binary['Result'] = data['Result'].isin([1, 3, 5]).astype(int)
data_binary.to_csv('ufc-master-for-binary-classification.csv')
data_binary
# Out:
#                 RedFighter           BlueFighter  WeightClass  Gender  \
# 0        Alexandre Pantoja           Kai Asakura            0       1
# 1        Shavkat Rakhmonov     Ian Machado Garry            4       1
# 2               Ciryl Gane      Alexander Volkov            7       1
# 3           Bryce Mitchell           Kron Gracie            2       1
# 4            Nate Landwehr            Dooho Choi            2       1
# ...                    ...                   ...          ...     ...
# 1495  Jack Della Maddalena        Pete Rodriguez            4       1
# 1496          Tony Gravely       Saimon Oliveira            1       1
# 1497          Matt Frevola         Genaro Valdez            3       1
# 1498  Silvana Gomez Juarez    Vanessa Demopoulos            0       0
# 1499            Kay Hansen  Jasmine Jasudavicius            0       0
#
#       NumberOfRounds  RedAge  RedHeightCms  RedReachCms  RedWeightLbs  \
# 0                  0      34        165.10       170.18           125
# 1                  1      30        185.42       195.58           170
# 2                  1      34        193.04       205.74           245
# 3                  1      30        177.80       177.80           145
# 4                  1      36        175.26       182.88           145
# ...              ...     ...           ...          ...           ...
# 1495               1      25        180.34       185.42           170
# 1496               1      30        165.10       175.26           135
# 1497               1      31        175.26       180.34           155
# 1498               1      37        160.02       165.10           115
# 1499               1      22        157.48       160.02           115
#
#       RedStance  ...  BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  \
# 0           1.0  ...              0.00            0.0             0.00
# 1           1.0  ...              0.55            0.3             0.77
# 2           1.0  ...              0.57            0.2             0.45
# 3           0.0  ...              0.44            0.5             0.47
# 4           1.0  ...              0.53            0.8             0.75
# ...         ...  ...               ...            ...              ...
# 1495        1.0  ...              0.46            0.0             0.00
# 1496        1.0  ...              0.41            1.6             1.21
# 1497        1.0  ...              0.30            0.4             1.54
# 1498        1.0  ...              0.42            0.8             0.58
# 1499        1.0  ...              0.41            0.0             2.20
#
#       BlueAvgTDPct  BlueTotalRoundsFought  Result  RedWinsByDecision  \
# 0             0.00                      0       0                  6
# 1             0.55                     20       0                  0
# 2             0.63                     44       0                  3
# 3             0.25                      7       0                  6
# 4             0.37                     15       1                  2
# ...            ...                    ...     ...                ...
# 1495          0.00                      0       0                  1
# 1496          0.25                      3       0                  1
# 1497          0.44                      2       0                  2
# 1498          0.13                      6       1                  0
# 1499          0.44                      3       1                  0
#
#       RedWinsByKO/TKO  BlueWinsByDecision  BlueWinsByKO/TKO
# 0                   2                   0                 0
# 1                   1                   5                 3
# 2                   4                   5                 6
# 3                   0                   0                 0
# 4                   1                   0                 4
# ...               ...                 ...               ...
# 1495                0                   0                 0
# 1496                2                   1                 0
# 1497                0                   0                 1
# 1498                0                   0                 0
# 1499                0                   1                 0
#
# [1500 rows x 42 columns]

# %%
data_binary['Result'].value_counts(normalize='True')
# Out:
# Result
# 0    0.566667
# 1    0.433333
# Name: proportion, dtype: float64

# %%
X = data_binary.drop(columns=['Result', 
                              'RedFighter', 
                              'BlueFighter', 
                            #   'WeightClass', 
                              # 'RedStance', 
                              # 'BlueStance'
                              ], axis=1)
y = data_binary['Result']



X_train = X.iloc[test_size:, :]
y_train = y.iloc[test_size:]
X_test = X.iloc[:test_size, :]
y_test = y.iloc[:test_size]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=8)

# %%
X_train
# Out:
#       WeightClass  Gender  NumberOfRounds  RedAge  RedHeightCms  RedReachCms  \
# 300             1       1               1      32        165.10       167.64
# 301             0       0               1      35        157.48       149.86
# 302             7       1               0      39        190.50       200.66
# 303             4       1               1      30        177.80       193.04
# 304             6       1               1      36        182.88       193.04
# ...           ...     ...             ...     ...           ...          ...
# 1495            4       1               1      25        180.34       185.42
# 1496            1       1               1      30        165.10       175.26
# 1497            3       1               1      31        175.26       180.34
# 1498            0       0               1      37        160.02       165.10
# 1499            0       0               1      22        157.48       160.02
#
#       RedWeightLbs  RedStance  RedWins  RedWinsBySubmission  ...  \
# 300            135        1.0        4                    0  ...
# 301            115        1.0        4                    1  ...
# 302            260        1.0       18                    0  ...
# 303            170        0.0        8                    0  ...
# 304            205        1.0       10                    2  ...
# ...            ...        ...      ...                  ...  ...
# 1495           170        1.0        1                    0  ...
# 1496           135        1.0        3                    0  ...
# 1497           155        1.0        3                    1  ...
# 1498           115        1.0        0                    0  ...
# 1499           115        1.0        1                    1  ...
#
#       BlueAvgSigStrLanded  BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  \
# 300                  4.58              0.57            0.6             0.60
# 301                  7.45              0.52            0.0             0.20
# 302                  4.05              0.49            0.6             1.23
# 303                  2.50              0.43            0.0             0.77
# 304                  7.41              0.59            0.3             0.95
# ...                   ...               ...            ...              ...
# 1495                10.37              0.46            0.0             0.00
# 1496                 2.82              0.41            1.6             1.21
# 1497                 4.08              0.30            0.4             1.54
# 1498                 3.71              0.42            0.8             0.58
# 1499                 3.23              0.41            0.0             2.20
#
#       BlueAvgTDPct  BlueTotalRoundsFought  RedWinsByDecision  RedWinsByKO/TKO  \
# 300           0.22                      8                  3                1
# 301           0.14                     12                  3                0
# 302           0.37                     15                  4               14
# 303           1.00                      2                  2                6
# 304           0.75                     12                  2                6
# ...            ...                    ...                ...              ...
# 1495          0.00                      0                  1                0
# 1496          0.25                      3                  1                2
# 1497          0.44                      2                  2                0
# 1498          0.13                      6                  0                0
# 1499          0.44                      3                  0                0
#
#       BlueWinsByDecision  BlueWinsByKO/TKO
# 300                    1                 1
# 301                    2                 0
# 302                    3                 0
# 303                    0                 2
# 304                    1                 4
# ...                  ...               ...
# 1495                   0                 0
# 1496                   1                 0
# 1497                   0                 1
# 1498                   0                 0
# 1499                   1                 0
#
# [1200 rows x 39 columns]

# %%
pipeline = Pipeline([('imputer', SimpleImputer(strategy='mean')),
                     ('scaler', MinMaxScaler()),
                     ('logreg', LogisticRegression(max_iter=1000))
                     ])

params = {'logreg__penalty': [None, 'l1', 'l2'],
          'logreg__C': np.linspace(0.001, 10000, 24),
          'logreg__solver': ['liblinear', 'lbfgs', 'newton-cs'],
          'logreg__class_weight': ['none', 'balanced'],
          'logreg__fit_intercept': [True, False]}

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=8)

gs_binary = GridSearchCV(estimator=pipeline, param_grid=params, cv=folds, scoring='f1', verbose=True, n_jobs=-1)

# Обучаем pipeline на тренировочных данных
gs_binary.fit(X_train, y_train)

# Делаем прогнозы на тестовых данных
y_pred = gs_binary.predict(X_test)

# Выводим метрики качества модели
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Матрица ошибок

sns.heatmap(confusion_matrix(y_test, y_pred),  annot=True, fmt="d", cmap='Greens')
plt.ylabel('Real value')
plt.xlabel('predicted value')
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       165
#            1       0.66      0.64      0.65       135
#
#     accuracy                           0.69       300
#    macro avg       0.69      0.69      0.69       300
# weighted avg       0.69      0.69      0.69       300
# Text(0.5, 23.52222222222222, 'predicted value')

# %%
gs_binary.best_params_
# Out:
# {'logreg__C': np.float64(869.5661304347826),
#  'logreg__class_weight': 'balanced',
#  'logreg__fit_intercept': False,
#  'logreg__penalty': 'l2',
#  'logreg__solver': 'liblinear'}

# %%
# Предсказание вероятностей
y_proba = gs_binary.predict_proba(X_test)

# Создание датафрейма для хранения результатов
results_df = pd.DataFrame({
    'RedFighter': data_binary['RedFighter'].iloc[:test_size],
    'BlueFighter': data_binary['BlueFighter'].iloc[:test_size],
    'ProbabilityRedWins': y_proba [:, 0],
    'ProbabilityBlueWins': y_proba [:, 1],
    'ActualWinner': data_binary['Result'].iloc[:test_size]
})

# for i in range(len(X_test)):
#     print(f"Вероятность победы {data_binary.loc[i, 'RedFighter']}: {y_proba[i][0] * 100:.2f}% Вероятность победы {data_binary.loc[i, 'BlueFighter']}: {y_proba[i][1] * 100:.2f}%")


# # Метрики
# print("Log Loss:", log_loss(y_test, y_proba))
# print("ROC-AUC:", roc_auc_score(y_test, y_proba[:, 1]))
results_df
# Out:
#             RedFighter        BlueFighter  ProbabilityRedWins  \
# 0    Alexandre Pantoja        Kai Asakura            0.984341
# 1    Shavkat Rakhmonov  Ian Machado Garry            0.447650
# 2           Ciryl Gane   Alexander Volkov            0.568862
# 3       Bryce Mitchell        Kron Gracie            0.832963
# 4        Nate Landwehr         Dooho Choi            0.500047
# ..                 ...                ...                 ...
# 295    Victor Martinez          Tom Nolan            0.436066
# 296           Oumar Sy        Tuco Tokkos            0.754984
# 297      Tamires Vidal      Melissa Gatto            0.352061
# 298     Abus Magomedov      Warlley Alves            0.426672
# 299    Piera Rodriguez  Ariane Carnelossi            0.500413
#
#      ProbabilityBlueWins  ActualWinner
# 0               0.015659             0
# 1               0.552350             0
# 2               0.431138             0
# 3               0.167037             0
# 4               0.499953             1
# ..                   ...           ...
# 295             0.563934             1
# 296             0.245016             0
# 297             0.647939             1
# 298             0.573328             0
# 299             0.499587             1
#
# [300 rows x 5 columns]

# %% [markdown]
# ### Разбираемся с вероятностями

# %%
# Калибровочная кривая
y_proba_positive = y_proba[:, 1]  # Вероятности положительного класса
prob_true, prob_pred = calibration_curve(y_test, y_proba_positive, n_bins=10, strategy="uniform")

# Построение графика
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Калибровочная кривая')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Идеальная калибровка')
plt.xlabel('Предсказанная вероятность')
plt.ylabel('Эмпирическая вероятность')
plt.title('График калибровки логистической регрессии')
plt.legend()

# %%
from sklearn.calibration import CalibratedClassifierCV

model = gs_binary.best_estimator_
# Предсказываем вероятности
y_proba_positive = y_proba[:, 1]  # Вероятности положительного класса
calibrated_model = CalibratedClassifierCV(estimator=model, method='isotonic', cv='prefit')
calibrated_model.fit(X_test, y_test)
# Предсказанные вероятности после калибровки
calibrated_proba = calibrated_model.predict_proba(X_test)[:, 1]
# # Калибровочная кривая
prob_true, prob_pred = calibration_curve(y_test, calibrated_proba, n_bins=10, strategy="uniform")
# Построение графика
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Калибровочная кривая')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Идеальная калибровка')
plt.xlabel('Предсказанная вероятность')
plt.ylabel('Эмпирическая вероятность')
plt.title('График калибровки логистической регрессии')
plt.legend()

# %%
y_pred_calibrated = calibrated_model.predict(X_test)
# Выводим метрики качества модели
print("Classification Report:")
print(classification_report(y_test, y_pred_calibrated))

# Матрица ошибок

sns.heatmap(confusion_matrix(y_test, y_pred_calibrated),  annot=True, fmt="d", cmap='Greens')
plt.ylabel('Real value')
plt.xlabel('predicted value')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       165
#            1       0.74      0.56      0.64       135
#
#     accuracy                           0.71       300
#    macro avg       0.72      0.70      0.70       300
# weighted avg       0.72      0.71      0.71       300
# Text(0.5, 23.52222222222222, 'predicted value')

# %%
# Предсказанные вероятности после калибровки
calibrated_proba = calibrated_model.predict_proba(X_test)

# Создание датафрейма для хранения результатов
results_df = pd.DataFrame({
    'RedFighter': data_binary['RedFighter'].iloc[:test_size],
    'BlueFighter': data_binary['BlueFighter'].iloc[:test_size],
    'ProbabilityRedWins': calibrated_proba [:, 0],
    'ProbabilityBlueWins': calibrated_proba [:, 1],
    'ActualWinner': data_binary['Result'].iloc[:test_size]
})

# for i in range(len(X_test)):
#     print(f"Вероятность победы {data_binary.loc[i, 'RedFighter']}: {calibrated_proba[i][0] * 100:.2f}% Вероятность победы {data_binary.loc[i, 'BlueFighter']}: {calibrated_proba[i][1] * 100:.2f}%")
#     # print(f"Вероятность победы {data_binary.loc[i, 'BlueFighter']}: {y_proba[i][1] * 100:.2f}%")

# # Метрики
# print("Log Loss:", log_loss(y_test, calibrated_proba))
# print("ROC-AUC:", roc_auc_score(y_test, calibrated_proba[:, 1]))
results_df.iloc[0:30, :]
# Out:
#                   RedFighter          BlueFighter  ProbabilityRedWins  \
# 0          Alexandre Pantoja          Kai Asakura            1.000000
# 1          Shavkat Rakhmonov    Ian Machado Garry            0.555556
# 2                 Ciryl Gane     Alexander Volkov            0.562500
# 3             Bryce Mitchell          Kron Gracie            0.882353
# 4              Nate Landwehr           Dooho Choi            0.562500
# 5             Dominick Reyes        Anthony Smith            0.769231
# 6              Vicente Luque       Themba Gorimbo            0.195122
# 7              Movsar Evloev    Aljamain Sterling            0.769231
# 8                Randy Brown         Bryan Battle            0.391304
# 9              Chris Weidman          Eryk Anders            0.769231
# 10               Cody Durden           Joshua Van            0.195122
# 11            Michael Chiesa          Max Griffin            0.562500
# 12                Clay Guida         Chase Hooper            0.111111
# 13         Kennedy Nzechukwu       Lukasz Brzeski            0.562500
# 14                  Petr Yan  Deiveson Figueiredo            0.562500
# 15               Yan Xiaonan        Tabatha Ricci            0.562500
# 16                Song Kenan      Muslim Salikhov            0.666667
# 17                 Wang Cong  Gabriella Fernandes            0.812500
# 18           Volkan Oezdemir        Carlos Ulberg            0.195122
# 19            Zhang Mingyang            Ozzy Diaz            1.000000
# 20        Baergeng Jieleyisi          SuYoung You            0.388889
# 21               Kiru Sahota         DongHun Choi            0.391304
# 22                  Shi Ming         Feng Xiaocan            0.111111
# 23  Nyamjargal Tumendemberel     Carlos Hernandez            0.769231
# 24          Lone'er Kavanagh           Jose Ochoa            0.562500
# 25                 Xiao Long             Quang Le            0.882353
# 26                 Maheshate        Nikolas Motta            0.562500
# 27                 Jon Jones         Stipe Miocic            1.000000
# 28          Charles Oliveira     Michael Chandler            0.562500
# 29                 Bo Nickal           Paul Craig            1.000000
#
#     ProbabilityBlueWins  ActualWinner
# 0              0.000000             0
# 1              0.444444             0
# 2              0.437500             0
# 3              0.117647             0
# 4              0.437500             1
# 5              0.230769             0
# 6              0.804878             0
# 7              0.230769             0
# 8              0.608696             1
# 9              0.230769             1
# 10             0.804878             1
# 11             0.437500             0
# 12             0.888889             1
# 13             0.437500             0
# 14             0.437500             0
# 15             0.437500             0
# 16             0.333333             1
# 17             0.187500             1
# 18             0.804878             1
# 19             0.000000             0
# 20             0.611111             1
# 21             0.608696             1
# 22             0.888889             0
# 23             0.230769             1
# 24             0.437500             0
# 25             0.117647             0
# 26             0.437500             1
# 27             0.000000             0
# 28             0.437500             0
# 29             0.000000             0

# %%
# Извлекаем scaler из пайплайна
scaler = pipeline.named_steps['scaler']

# Применяем scaler к данным
processed_data = scaler.fit_transform(X_train)
scaled_df = pd.DataFrame(processed_data, columns=X_train.columns)
# Выводим обработанные данные
scaled_df
# Out:
#       WeightClass  Gender  NumberOfRounds    RedAge  RedHeightCms  \
# 0        0.142857     1.0             1.0  0.538462      0.263158
# 1        0.000000     0.0             1.0  0.653846      0.105263
# 2        1.000000     1.0             0.0  0.807692      0.789474
# 3        0.571429     1.0             1.0  0.461538      0.526316
# 4        0.857143     1.0             1.0  0.692308      0.631579
# ...           ...     ...             ...       ...           ...
# 1195     0.571429     1.0             1.0  0.269231      0.578947
# 1196     0.142857     1.0             1.0  0.461538      0.263158
# 1197     0.428571     1.0             1.0  0.500000      0.473684
# 1198     0.000000     0.0             1.0  0.730769      0.157895
# 1199     0.000000     0.0             1.0  0.153846      0.105263
#
#       RedReachCms  RedWeightLbs  RedStance   RedWins  RedWinsBySubmission  \
# 0        0.307692      0.133333        1.0  0.148148               0.0000
# 1        0.038462      0.000000        1.0  0.148148               0.0625
# 2        0.807692      0.966667        1.0  0.666667               0.0000
# 3        0.692308      0.366667        0.0  0.296296               0.0000
# 4        0.692308      0.600000        1.0  0.370370               0.1250
# ...           ...           ...        ...       ...                  ...
# 1195     0.576923      0.366667        1.0  0.037037               0.0000
# 1196     0.423077      0.133333        1.0  0.111111               0.0000
# 1197     0.500000      0.266667        1.0  0.111111               0.0625
# 1198     0.269231      0.000000        1.0  0.000000               0.0000
# 1199     0.192308      0.000000        1.0  0.037037               0.0625
#
#       ...  BlueAvgSigStrLanded  BlueAvgSigStrPct  BlueAvgSubAtt  \
# 0     ...             0.430678          0.681159       0.071429
# 1     ...             0.712881          0.608696       0.000000
# 2     ...             0.378564          0.565217       0.071429
# 3     ...             0.226155          0.478261       0.000000
# 4     ...             0.708948          0.710145       0.035714
# ...   ...                  ...               ...            ...
# 1195  ...             1.000000          0.521739       0.000000
# 1196  ...             0.257620          0.449275       0.190476
# 1197  ...             0.381514          0.289855       0.047619
# 1198  ...             0.345133          0.463768       0.095238
# 1199  ...             0.297935          0.449275       0.000000
#
#       BlueAvgTDLanded  BlueAvgTDPct  BlueTotalRoundsFought  RedWinsByDecision  \
# 0            0.080645          0.22               0.074074           0.214286
# 1            0.026882          0.14               0.111111           0.214286
# 2            0.165323          0.37               0.138889           0.285714
# 3            0.103495          1.00               0.018519           0.142857
# 4            0.127688          0.75               0.111111           0.142857
# ...               ...           ...                    ...                ...
# 1195         0.000000          0.00               0.000000           0.071429
# 1196         0.162634          0.25               0.027778           0.071429
# 1197         0.206989          0.44               0.018519           0.142857
# 1198         0.077957          0.13               0.055556           0.000000
# 1199         0.295699          0.44               0.027778           0.000000
#
#       RedWinsByKO/TKO  BlueWinsByDecision  BlueWinsByKO/TKO
# 0            0.047619            0.076923          0.071429
# 1            0.000000            0.153846          0.000000
# 2            0.666667            0.230769          0.000000
# 3            0.285714            0.000000          0.142857
# 4            0.285714            0.076923          0.285714
# ...               ...                 ...               ...
# 1195         0.000000            0.000000          0.000000
# 1196         0.095238            0.076923          0.000000
# 1197         0.000000            0.000000          0.071429
# 1198         0.000000            0.000000          0.000000
# 1199         0.000000            0.076923          0.000000
#
# [1200 rows x 39 columns]

# %%
print(X.columns)
# Out:
# Index(['WeightClass', 'Gender', 'NumberOfRounds', 'RedAge', 'RedHeightCms',
#        'RedReachCms', 'RedWeightLbs', 'RedStance', 'RedWins',
#        'RedWinsBySubmission', 'RedCurrentWinStreak', 'RedLosses',
#        'RedCurrentLoseStreak', 'RedAvgSigStrLanded', 'RedAvgSigStrPct',
#        'RedAvgSubAtt', 'RedAvgTDLanded', 'RedAvgTDPct', 'RedTotalRoundsFought',
#        'BlueAge', 'BlueHeightCms', 'BlueReachCms', 'BlueWeightLbs',
#        'BlueStance', 'BlueWins', 'BlueWinsBySubmission',
#        'BlueCurrentWinStreak', 'BlueLosses', 'BlueCurrentLoseStreak',
#        'BlueAvgSigStrLanded', 'BlueAvgSigStrPct', 'BlueAvgSubAtt',
#        'BlueAvgTDLanded', 'BlueAvgTDPct', 'BlueTotalRoundsFought',
#        'RedWinsByDecision', 'RedWinsByKO/TKO', 'BlueWinsByDecision',
#        'BlueWinsByKO/TKO'],
#       dtype='object')

# %% [markdown]
# ### Создание новых признаков

# %%
X_featured = deepcopy(X)
# Создаем новые признаки
X_featured['Age_diff'] = X_featured['RedAge'] - X_featured['BlueAge']
X_featured['Height_diff'] = X_featured['RedHeightCms'] - X_featured['BlueHeightCms']
X_featured['Reach_diff'] = X_featured['RedReachCms'] - X_featured['BlueReachCms']
X_featured['Weight_diff'] = X_featured['RedWeightLbs'] - X_featured['BlueWeightLbs']
X_featured['Red_wins_loss_diff'] = X_featured['RedWins'] - X_featured['RedLosses']
X_featured['Blue_wins_loss_diff'] = X_featured['BlueWins'] - X_featured['BlueLosses']
X_featured['Red_Blue_Wins_diff'] = X_featured['RedWins'] - X_featured['BlueWins']
X_featured['Red_Blue_Loss_diff'] = X_featured['RedLosses'] - X_featured['BlueLosses']

# Находим разницу между числом побед-поражений для обоих бойцов
X_featured['Red_Blue_wins_loss_diff'] = X_featured['Red_wins_loss_diff'] - X_featured['Blue_wins_loss_diff']

# %%
def red_blue_streak_diff_calc(row):
    if row['RedCurrentWinStreak'] > 0: 
        if row['BlueCurrentWinStreak'] > 0:
            return row['RedCurrentWinStreak'] - row['BlueCurrentWinStreak']
        else:
            return row['RedCurrentWinStreak'] + row['BlueCurrentLoseStreak']
    else:
        if row['BlueCurrentWinStreak'] > 0:
            return -row['RedCurrentLoseStreak'] - row['BlueCurrentWinStreak']
        else:
            return -row['RedCurrentLoseStreak'] + row['BlueCurrentLoseStreak']
        
X_featured['Red_Blue_curr_streak_diff'] = X_featured.apply(red_blue_streak_diff_calc, axis=1)

# %%
# Создаем новые признаки, касающиеся статистики бойцов
X_featured['RedSignStrikesAverage'] = X_featured['RedAvgSigStrLanded'] * X_featured['RedAvgSigStrPct']
X_featured['BlueSignStrikesAverage'] = X_featured['BlueAvgSigStrLanded'] * X_featured['BlueAvgSigStrPct']

X_featured['RedSuccesfullTDAverage'] = X_featured['RedAvgTDLanded'] * X_featured['RedAvgTDPct']
X_featured['BlueSuccesfullTDAverage'] = X_featured['BlueAvgTDLanded'] * X_featured['BlueAvgTDPct']

# Найдем разницу между статистическими показателями бойцов
X_featured['Red_Blue_SignStrikAvg_diff'] = X_featured['RedSignStrikesAverage'] - X_featured['BlueSignStrikesAverage'] 
X_featured['Red_Blue_SuccTDAvg_diff'] = X_featured['RedSuccesfullTDAverage'] - X_featured['BlueSuccesfullTDAverage'] 
X_featured['Red_Blue_AvgSubAtt_diff'] = X_featured['RedAvgSubAtt'] - X_featured['BlueAvgSubAtt']

# %% [markdown]
# Добавим вторую степень некоторых признаков

# %%
# X_featured['Red_Blue_SignStrikAvg_diff_2'] = np.pow(X_featured['Red_Blue_SignStrikAvg_diff'], 2)
# X_featured['Red_Blue_SuccTDAvg_diff_2'] = np.pow(X_featured['Red_Blue_SuccTDAvg_diff'], 2)
# X_featured['Red_Blue_AvgSubAtt_diff_2'] = np.pow(X_featured['Red_Blue_AvgSubAtt_diff'], 2)

# %%
X_featured
# Out:
#       WeightClass  Gender  NumberOfRounds  RedAge  RedHeightCms  RedReachCms  \
# 0               0       1               0      34        165.10       170.18
# 1               4       1               1      30        185.42       195.58
# 2               7       1               1      34        193.04       205.74
# 3               2       1               1      30        177.80       177.80
# 4               2       1               1      36        175.26       182.88
# ...           ...     ...             ...     ...           ...          ...
# 1495            4       1               1      25        180.34       185.42
# 1496            1       1               1      30        165.10       175.26
# 1497            3       1               1      31        175.26       180.34
# 1498            0       0               1      37        160.02       165.10
# 1499            0       0               1      22        157.48       160.02
#
#       RedWeightLbs  RedStance  RedWins  RedWinsBySubmission  ...  \
# 0              125        1.0       12                    4  ...
# 1              170        1.0        6                    5  ...
# 2              245        1.0        9                    2  ...
# 3              145        0.0        7                    1  ...
# 4              145        1.0        5                    2  ...
# ...            ...        ...      ...                  ...  ...
# 1495           170        1.0        1                    0  ...
# 1496           135        1.0        3                    0  ...
# 1497           155        1.0        3                    1  ...
# 1498           115        1.0        0                    0  ...
# 1499           115        1.0        1                    1  ...
#
#       Red_Blue_Loss_diff  Red_Blue_wins_loss_diff  Red_Blue_curr_streak_diff  \
# 0                      3                        9                        6.0
# 1                      0                       -2                       -2.0
# 2                     -2                       -1                       -3.0
# 3                      0                        6                        1.0
# 4                      0                        1                        0.0
# ...                  ...                      ...                        ...
# 1495                   0                        1                        1.0
# 1496                   2                        0                       -2.0
# 1497                   3                       -1                       -3.0
# 1498                  -1                        1                        1.0
# 1499                   1                       -1                       -2.0
#
#       RedSignStrikesAverage  BlueSignStrikesAverage  RedSuccesfullTDAverage  \
# 0                    2.1609                  0.0000                  1.2267
# 1                    2.5132                  3.0250                  0.4321
# 2                    3.2940                  2.9241                  0.1218
# 3                    1.3340                  1.6456                  1.4145
# 4                    2.8750                  2.3373                  0.4100
# ...                     ...                     ...                     ...
# 1495                 3.7804                  4.7702                  0.0720
# 1496                 1.8336                  1.1562                  2.2140
# 1497                 1.5252                  1.2240                  0.8136
# 1498                 1.3632                  1.5582                  0.0000
# 1499                 1.5050                  1.3243                  0.4026
#
#       BlueSuccesfullTDAverage  Red_Blue_SignStrikAvg_diff  \
# 0                      0.0000                      2.1609
# 1                      0.4235                     -0.5118
# 2                      0.2835                      0.3699
# 3                      0.1175                     -0.3116
# 4                      0.2775                      0.5377
# ...                       ...                         ...
# 1495                   0.0000                     -0.9898
# 1496                   0.3025                      0.6774
# 1497                   0.6776                      0.3012
# 1498                   0.0754                     -0.1950
# 1499                   0.9680                      0.1807
#
#       Red_Blue_SuccTDAvg_diff  Red_Blue_AvgSubAtt_diff
# 0                      1.2267                      0.8
# 1                      0.0086                      1.5
# 2                     -0.1617                      0.3
# 3                      1.2970                      1.1
# 4                      0.1325                      0.2
# ...                       ...                      ...
# 1495                   0.0720                      0.4
# 1496                   1.9115                     -1.3
# 1497                   0.1360                      0.5
# 1498                  -0.0754                     -0.8
# 1499                  -0.5654                      0.8
#
# [1500 rows x 56 columns]

# %%
# Убираем исходные признаки и оставляем только созданные
X_featured = X_featured.drop(columns=[
                                     'RedAge',
                                     'RedHeightCms',
                                     'RedReachCms',
                                     'RedWeightLbs',
                                     'BlueAge',
                                     'BlueHeightCms',
                                     'BlueReachCms',
                                     'BlueWeightLbs',
                                     'RedWins',
                                     'RedLosses',
                                     'BlueWins',
                                     'BlueLosses',
                                     'RedCurrentWinStreak',
                                     'RedCurrentLoseStreak',
                                     'RedTotalRoundsFought',
                                     'BlueCurrentWinStreak',
                                     'BlueCurrentLoseStreak',
                                    #  'Red_wins_loss_diff',
                                    #  'Blue_wins_loss_diff',                                     
                                    #  'WeightClass',
                                     'RedAvgSigStrLanded',
                                     'RedAvgSigStrPct',
                                     'BlueAvgSigStrLanded',
                                     'BlueAvgSigStrPct',
                                     'RedAvgTDLanded',
                                     'RedAvgTDPct', 
                                     'BlueAvgTDLanded',
                                     'BlueAvgTDPct',
                                     'RedAvgSubAtt',
                                     'RedSignStrikesAverage',
                                     'BlueSignStrikesAverage',
                                     'RedSuccesfullTDAverage',
                                     'BlueSuccesfullTDAverage',
                                     'BlueAvgSubAtt',
                                     'Gender',
                                     'NumberOfRounds',
                                     'RedWinsBySubmission',
                                     'BlueWinsBySubmission',
                                     'RedWinsByDecision',
                                     'RedWinsByKO/TKO',
                                     'BlueWinsByDecision',
                                     'BlueWinsByKO/TKO',
                                     'BlueTotalRoundsFought'                                    
                                     ])

# %%
X_featured.to_csv('ufc-master-for-binary-classification_featured.csv')

# %%
X_train = X_featured.iloc[test_size:, :]
y_train = y.iloc[test_size:]
X_test = X_featured.iloc[:test_size]
y_test = y.iloc[:test_size]

X_train
# Out:
#       WeightClass  RedStance  BlueStance  Age_diff  Height_diff  Reach_diff  \
# 300             1        1.0         1.0         4         0.00       -2.54
# 301             0        1.0         1.0         5         0.00      -10.16
# 302             7        1.0         1.0         8         2.54       -2.54
# 303             4        0.0         1.0         0       -17.78        0.00
# 304             6        1.0         1.0         3       -10.16       -2.54
# ...           ...        ...         ...       ...          ...         ...
# 1495            4        1.0         1.0         0         5.08        5.08
# 1496            1        1.0         1.0         0         2.54       -7.62
# 1497            3        1.0         1.0         1         0.00       -2.54
# 1498            0        1.0         1.0         4         2.54       15.24
# 1499            0        1.0         1.0       -10       -12.70      -12.70
#
#       Weight_diff  Red_wins_loss_diff  Blue_wins_loss_diff  \
# 300             0                   2                    0
# 301             0                   1                    0
# 302            14                   8                    4
# 303             0                   4                    2
# 304             0                   7                    5
# ...           ...                 ...                  ...
# 1495           15                   1                    0
# 1496            0                   1                    1
# 1497            0                   0                    1
# 1498            0                  -1                   -2
# 1499          -10                   0                    1
#
#       Red_Blue_Wins_diff  Red_Blue_Loss_diff  Red_Blue_wins_loss_diff  \
# 300                    2                   0                        2
# 301                    2                   1                        1
# 302                   13                   9                        4
# 303                    6                   4                        2
# 304                    4                   2                        2
# ...                  ...                 ...                      ...
# 1495                   1                   0                        1
# 1496                   2                   2                        0
# 1497                   2                   3                       -1
# 1498                   0                  -1                        1
# 1499                   0                   1                       -1
#
#       Red_Blue_curr_streak_diff  Red_Blue_SignStrikAvg_diff  \
# 300                         0.0                     -1.7658
# 301                         0.0                     -2.2873
# 302                        -4.0                     -0.7445
# 303                         1.0                      0.4118
# 304                        -1.0                     -2.3361
# ...                         ...                         ...
# 1495                        1.0                     -0.9898
# 1496                       -2.0                      0.6774
# 1497                       -3.0                      0.3012
# 1498                        1.0                     -0.1950
# 1499                       -2.0                      0.1807
#
#       Red_Blue_SuccTDAvg_diff  Red_Blue_AvgSubAtt_diff
# 300                    0.7635                     -0.6
# 301                    0.0171                      0.5
# 302                   -0.3069                     -0.6
# 303                    0.1316                      0.0
# 304                   -0.5046                     -0.1
# ...                       ...                      ...
# 1495                   0.0720                      0.4
# 1496                   1.9115                     -1.3
# 1497                   0.1360                      0.5
# 1498                  -0.0754                     -0.8
# 1499                  -0.5654                      0.8
#
# [1200 rows x 16 columns]

# %%
# Обучаем pipeline на тренировочных данных
gs_binary.fit(X_train, y_train)

# Делаем прогнозы на тестовых данных
y_pred = gs_binary.predict(X_test)

# Выводим метрики качества модели
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Матрица ошибок
sns.heatmap(confusion_matrix(y_test, y_pred),  annot=True, fmt="d", cmap='Greens')
plt.ylabel('Real value')
plt.xlabel('predicted value')
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/neuralist/DS&ML/Data_Science/MIPT_Data_Scientist/DA & ML/UFC-predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.73       165
#            1       0.67      0.65      0.66       135
#
#     accuracy                           0.70       300
#    macro avg       0.69      0.69      0.69       300
# weighted avg       0.70      0.70      0.70       300
# Text(0.5, 23.52222222222222, 'predicted value')

# %%
# Калибровочная кривая
y_proba_positive = y_proba[:, 1]  # Вероятности положительного класса
prob_true, prob_pred = calibration_curve(y_test, y_proba_positive, n_bins=10, strategy="uniform")

# Калибруем вероятности
model = gs_binary.best_estimator_
# Предсказываем вероятности
y_proba_positive = y_proba[:, 1]  # Вероятности положительного класса
calibrated_model = CalibratedClassifierCV(estimator=model, method='isotonic', cv='prefit')
calibrated_model.fit(X_test, y_test)
# Предсказанные вероятности после калибровки
calibrated_proba = calibrated_model.predict_proba(X_test)[:, 1]
# # Калибровочная кривая
prob_true, prob_pred = calibration_curve(y_test, calibrated_proba, n_bins=10, strategy="uniform")

y_pred_calibrated = calibrated_model.predict(X_test)
# Выводим метрики качества модели
print("Classification Report:")
print(classification_report(y_test, y_pred_calibrated))

# Матрица ошибок

sns.heatmap(confusion_matrix(y_test, y_pred_calibrated),  annot=True, fmt="d", cmap='Greens')
plt.ylabel('Real value')
plt.xlabel('predicted value')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.74       165
#            1       0.68      0.71      0.69       135
#
#     accuracy                           0.72       300
#    macro avg       0.71      0.72      0.71       300
# weighted avg       0.72      0.72      0.72       300
# Text(0.5, 23.52222222222222, 'predicted value')

# %%
# Предсказанные вероятности после калибровки
calibrated_proba = calibrated_model.predict_proba(X_test)


# Создание датафрейма для хранения результатов
results_df = pd.DataFrame({
    'RedFighter': data_binary['RedFighter'].iloc[:test_size],
    'BlueFighter': data_binary['BlueFighter'].iloc[:test_size],
    'ProbabilityRedWins': calibrated_proba [:, 0],
    'ProbabilityBlueWins': calibrated_proba [:, 1],
    'ActualWinner': data_binary['Result'].iloc[:test_size]
})

# %%
results_df['Predicted_Winner'] = (results_df['ProbabilityBlueWins'] > results_df['ProbabilityRedWins']).astype(int)
results_df['Prediction_Errors'] = np.abs(results_df['Predicted_Winner'] - results_df['ActualWinner'])
results_df.iloc[:30, :]
# Out:
#                   RedFighter          BlueFighter  ProbabilityRedWins  \
# 0          Alexandre Pantoja          Kai Asakura            0.900000
# 1          Shavkat Rakhmonov    Ian Machado Garry            0.400000
# 2                 Ciryl Gane     Alexander Volkov            0.600000
# 3             Bryce Mitchell          Kron Gracie            0.894737
# 4              Nate Landwehr           Dooho Choi            0.600000
# 5             Dominick Reyes        Anthony Smith            0.800000
# 6              Vicente Luque       Themba Gorimbo            0.400000
# 7              Movsar Evloev    Aljamain Sterling            0.866667
# 8                Randy Brown         Bryan Battle            0.400000
# 9              Chris Weidman          Eryk Anders            0.600000
# 10               Cody Durden           Joshua Van            0.166667
# 11            Michael Chiesa          Max Griffin            0.666667
# 12                Clay Guida         Chase Hooper            0.000000
# 13         Kennedy Nzechukwu       Lukasz Brzeski            0.666667
# 14                  Petr Yan  Deiveson Figueiredo            0.750000
# 15               Yan Xiaonan        Tabatha Ricci            0.454545
# 16                Song Kenan      Muslim Salikhov            0.750000
# 17                 Wang Cong  Gabriella Fernandes            0.894737
# 18           Volkan Oezdemir        Carlos Ulberg            0.166667
# 19            Zhang Mingyang            Ozzy Diaz            0.916667
# 20        Baergeng Jieleyisi          SuYoung You            0.400000
# 21               Kiru Sahota         DongHun Choi            0.400000
# 22                  Shi Ming         Feng Xiaocan            0.166667
# 23  Nyamjargal Tumendemberel     Carlos Hernandez            0.750000
# 24          Lone'er Kavanagh           Jose Ochoa            0.454545
# 25                 Xiao Long             Quang Le            0.894737
# 26                 Maheshate        Nikolas Motta            0.666667
# 27                 Jon Jones         Stipe Miocic            0.916667
# 28          Charles Oliveira     Michael Chandler            0.750000
# 29                 Bo Nickal           Paul Craig            0.916667
#
#     ProbabilityBlueWins  ActualWinner  Predicted_Winner  Prediction_Errors
# 0              0.100000             0                 0                  0
# 1              0.600000             0                 1                  1
# 2              0.400000             0                 0                  0
# 3              0.105263             0                 0                  0
# 4              0.400000             1                 0                  1
# 5              0.200000             0                 0                  0
# 6              0.600000             0                 1                  1
# 7              0.133333             0                 0                  0
# 8              0.600000             1                 1                  0
# 9              0.400000             1                 0                  1
# 10             0.833333             1                 1                  0
# 11             0.333333             0                 0                  0
# 12             1.000000             1                 1                  0
# 13             0.333333             0                 0                  0
# 14             0.250000             0                 0                  0
# 15             0.545455             0                 1                  1
# 16             0.250000             1                 0                  1
# 17             0.105263             1                 0                  1
# 18             0.833333             1                 1                  0
# 19             0.083333             0                 0                  0
# 20             0.600000             1                 1                  0
# 21             0.600000             1                 1                  0
# 22             0.833333             0                 1                  1
# 23             0.250000             1                 0                  1
# 24             0.545455             0                 1                  1
# 25             0.105263             0                 0                  0
# 26             0.333333             1                 0                  1
# 27             0.083333             0                 0                  0
# 28             0.250000             0                 0                  0
# 29             0.083333             0                 0                  0

# %%
print(results_df['Prediction_Errors'].sum())
# Out:
# 85

# %%
print(results_df['Prediction_Errors'].sum()/len(y_test))
# Out:
# 0.2833333333333333

# %%
171/500
# Out:
# 0.342
