# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score
from scipy.stats import pearsonr

# %% [markdown]
# ### Датасет с базовыми признаками

# %%
data = pd.read_csv('data_preprocessed/data_3511.csv', index_col='Unnamed: 0')
data
# Out:
#       WeightClass  Gender  NumberOfRounds  RedAge  RedHeightCms  RedReachCms  \
# 1               4       1             0.0      30        185.42       195.58
# 2               7       1             0.0      34        193.04       205.74
# 3               2       1             0.0      30        177.80       177.80
# 4               2       1             0.0      36        175.26       182.88
# 5               6       1             0.0      34        193.04       195.58
# ...           ...     ...             ...     ...           ...          ...
# 6508            7       1             1.0      30        190.50       200.66
# 6512            4       1             0.0      24        182.88       193.04
# 6518            7       1             0.0      26        193.04       195.58
# 6521            3       1             0.0      28        170.18       177.80
# 6525            7       1             0.0      27        193.04       198.12
#
#       RedWeightLbs  RedStance  RedWins  RedWinsBySubmission  ...  \
# 1              170        1.0        6                    5  ...
# 2              245        1.0        9                    2  ...
# 3              145        0.0        7                    1  ...
# 4              145        1.0        5                    2  ...
# 5              205        0.0        7                    1  ...
# ...            ...        ...      ...                  ...  ...
# 6508           264        0.0       11                    7  ...
# 6512           170        0.0        6                    5  ...
# 6518           238        1.0        4                    0  ...
# 6521           155        1.0        5                    1  ...
# 6525           245        1.0        0                    0  ...
#
#       BlueAvgSigStrPct  BlueAvgSubAtt  BlueAvgTDLanded  BlueAvgTDPct  \
# 1                0.550           0.30           0.7700         0.550
# 2                0.570           0.20           0.4500         0.630
# 3                0.440           0.50           0.4700         0.250
# 4                0.530           0.80           0.7500         0.370
# 5                0.490           0.60           0.4600         0.260
# ...                ...            ...              ...           ...
# 6508             0.437           0.00           0.3333         0.167
# 6512             0.275           0.00           0.0000         0.000
# 6518             0.548           0.70           1.2000         0.572
# 6521             0.333           1.25           1.2500         0.663
# 6525             0.340           1.00           1.0000         1.000
#
#       BlueTotalRoundsFought  Result  RedWinsByDecision  RedWinsByKO/TKO  \
# 1                        20       0                  0                1
# 2                        44       0                  3                4
# 3                         7       0                  6                0
# 4                        15       1                  2                1
# 5                        63       0                  2                4
# ...                     ...     ...                ...              ...
# 6508                      3       1                  1                2
# 6512                      2       0                  1                0
# 6518                     16       0                  0                4
# 6521                      7       0                  3                1
# 6525                      1       0                  0                0
#
#       BlueWinsByDecision  BlueWinsByKO/TKO
# 1                      5                 3
# 2                      5                 6
# 3                      0                 0
# 4                      0                 4
# 5                      2                 7
# ...                  ...               ...
# 6508                   0                 3
# 6512                   0                 1
# 6518                   0                 5
# 6521                   0                 0
# 6525                   0                 0
#
# [3511 rows x 40 columns]

# %% [markdown]
# Расчет взаимной информации

# %%
X = data.drop('Result', axis=1)
y = data['Result']

feature_names = X.columns.tolist()  # список названий признаков

# Расчет взаимной информации для каждого признака
mi = mutual_info_classif(X, y)

# Отбор k наиболее информативных признаков
k = 12
selector = SelectKBest(mutual_info_classif, k=k)
X_selected = selector.fit_transform(X, y)

# Получение индексов отобранных признаков
indices = selector.get_support(indices=True)

# Вывод названий отобранных признаков
print("Отобранные признаки:")
for index in indices:
    print(feature_names[index])
# Out:
# Отобранные признаки:
# RedAge
# RedReachCms
# RedWeightLbs
# RedWins
# RedAvgSigStrPct
# RedAvgTDPct
# BlueHeightCms
# BlueReachCms
# BlueAvgSigStrLanded
# BlueAvgTDLanded
# BlueTotalRoundsFought
# BlueWinsByKO/TKO

# %% [markdown]
# Корреляционный анализ

# %%
# Расчет корреляции для каждого признака
corrs = []
for i in range(X.shape[1]):
    corr, _ = pearsonr(X.iloc[:, i], y)
    corrs.append(corr)

# Отбор k наиболее коррелированных признаков
k = 12
idx = np.argsort(np.abs(corrs))[-k:]
X_selected = X.iloc[:, idx]
X_selected
# Out:
#       RedAvgTDPct  RedCurrentLoseStreak  BlueCurrentWinStreak  \
# 1           0.290                     0                     8
# 2           0.210                     0                     4
# 3           0.410                     1                     0
# 4           0.410                     0                     1
# 5           0.280                     0                     0
# ...           ...                   ...                   ...
# 6508        0.351                     0                     3
# 6512        0.476                     1                     0
# 6518        0.000                     0                     1
# 6521        0.382                     2                     0
# 6525        0.000                     1                     0
#
#       BlueAvgSigStrPct  BlueLosses  RedCurrentWinStreak  RedAvgTDLanded  \
# 1                0.550           0                    6          1.4900
# 2                0.570           4                    1          0.5800
# 3                0.440           2                    0          3.4500
# 4                0.530           3                    1          1.0000
# 5                0.490          12                    1          0.3500
# ...                ...         ...                  ...             ...
# 6508             0.437           0                    1          0.8000
# 6512             0.275           1                    0          1.3333
# 6518             0.548           3                    4          0.0000
# 6521             0.333           2                    0          3.4000
# 6525             0.340           1                    0          0.0000
#
#       BlueAvgTDLanded  RedAvgSigStrPct  RedLosses  RedAge  BlueAge
# 1              0.7700            0.610          0      30       27
# 2              0.4500            0.600          2      34       36
# 3              0.4700            0.580          2      30       36
# 4              0.7500            0.460          3      36       33
# 5              0.4600            0.500          4      34       36
# ...               ...              ...        ...     ...      ...
# 6508           0.3333            0.520          4      30       35
# 6512           0.0000            0.409          3      24       28
# 6518           1.2000            0.538          0      26       30
# 6521           1.2500            0.394          5      28       28
# 6525           1.0000            0.250          1      27       27
#
# [3511 rows x 12 columns]

# %% [markdown]
# ### Датасет с созданными признаками

# %%
data = pd.read_csv('data_preprocessed/data_featured_3511.csv', index_col='Unnamed: 0')
data
# Out:
#       WeightClass  Gender  NumberOfRounds  RedStance  BlueStance  Result  \
# 1               4       1             0.0        1.0         1.0       0
# 2               7       1             0.0        1.0         1.0       0
# 3               2       1             0.0        0.0         0.0       0
# 4               2       1             0.0        1.0         1.0       1
# 5               6       1             0.0        0.0         1.0       0
# ...           ...     ...             ...        ...         ...     ...
# 6508            7       1             1.0        0.0         1.0       1
# 6512            4       1             0.0        0.0         1.0       0
# 6518            7       1             0.0        1.0         1.0       0
# 6521            3       1             0.0        1.0         1.0       0
# 6525            7       1             0.0        1.0         1.0       0
#
#       Age_diff  Height_diff  Reach_diff  Weight_diff  ...  \
# 1            3        -5.08        7.62            0  ...
# 2           -2        -7.62        2.54           -5  ...
# 3           -6         2.54        0.00            0  ...
# 4            3        -2.54        5.08            0  ...
# 5           -2         0.00        2.54            0  ...
# ...        ...          ...         ...          ...  ...
# 6508        -5         2.54       -2.54           -1  ...
# 6512        -4         0.00       12.70            0  ...
# 6518        -4         5.08        2.54           -4  ...
# 6521         0        -7.62       -2.54            0  ...
# 6525         0         2.54        2.12          -20  ...
#
#       Blue_wins_loss_diff  Red_Blue_Wins_diff  Red_Blue_Loss_diff  \
# 1                       8                  -2                   0
# 2                       8                  -3                  -2
# 3                      -1                   6                   0
# 4                       1                   1                   0
# 5                       3                  -8                  -8
# ...                   ...                 ...                 ...
# 6508                    3                   8                   4
# 6512                    0                   5                   2
# 6518                    4                  -3                  -3
# 6521                    0                   3                   3
# 6525                   -1                   0                   0
#
#       Red_Blue_wins_loss_diff  AvgSigStrLanded_diff  AvgSigStrPct_diff  \
# 1                          -2                 -1.38              0.060
# 2                          -1                  0.36              0.030
# 3                           6                 -1.44              0.140
# 4                           1                  1.84             -0.070
# 5                           0                  1.63              0.010
# ...                       ...                   ...                ...
# 6508                        4                  3.00              0.083
# 6512                        3                  0.57              0.134
# 6518                        0                 -9.04             -0.010
# 6521                        0                 -8.18              0.061
# 6525                        0                  4.00             -0.090
#
#       TDAvgLanded_diff  AvgTDPct_diff  AvgSubAtt_diff  \
# 1               0.7200         -0.260          1.5000
# 2               0.1300         -0.420          0.3000
# 3               2.9800          0.160          1.1000
# 4               0.2500          0.040          0.2000
# 5              -0.1100          0.020         -0.3000
# ...                ...            ...             ...
# 6508            0.4667          0.184          1.2667
# 6512            1.3333          0.476          1.4444
# 6518           -1.2000         -0.572         -0.7000
# 6521            2.1500         -0.281         -0.6500
# 6525           -1.0000         -1.000         -1.0000
#
#       Red_Blue_curr_streak_diff
# 1                            -2
# 2                            -3
# 3                             1
# 4                             0
# 5                             2
# ...                         ...
# 6508                         -2
# 6512                          0
# 6518                          3
# 6521                         -1
# 6525                          0
#
# [3511 rows x 21 columns]

# %% [markdown]
# Расчет взаимной информации

# %%
X = data.drop('Result', axis=1)
y = data['Result']

feature_names = X.columns.tolist()  # список названий признаков

# Расчет взаимной информации для каждого признака
mi = mutual_info_classif(X, y)

# Отбор k наиболее информативных признаков
k = 12
selector = SelectKBest(mutual_info_classif, k=k)
X_selected = selector.fit_transform(X, y)

# Получение индексов отобранных признаков
indices = selector.get_support(indices=True)

# Вывод названий отобранных признаков
print("Отобранные признаки:")
for index in indices:
    print(feature_names[index])
# Out:
# Отобранные признаки:
# NumberOfRounds
# RedStance
# BlueStance
# Age_diff
# Height_diff
# Red_Blue_wins_loss_diff
# AvgSigStrLanded_diff
# AvgSigStrPct_diff
# TDAvgLanded_diff
# AvgTDPct_diff
# AvgSubAtt_diff
# Red_Blue_curr_streak_diff

# %% [markdown]
# Корреляционный анализ

# %%
# Расчет корреляции для каждого признака
corrs = []
for i in range(X.shape[1]):
    corr, _ = pearsonr(X.iloc[:, i], y)
    corrs.append(corr)

# Отбор k наиболее коррелированных признаков
k = 12
idx = np.argsort(np.abs(corrs))[-k:]
X_selected = X.iloc[:, idx]
X_selected
# Out:
#       Red_wins_loss_diff  Height_diff  Red_Blue_wins_loss_diff  Reach_diff  \
# 1                      6        -5.08                       -2        7.62
# 2                      7        -7.62                       -1        2.54
# 3                      5         2.54                        6        0.00
# 4                      2        -2.54                        1        5.08
# 5                      3         0.00                        0        2.54
# ...                  ...          ...                      ...         ...
# 6508                   7         2.54                        4       -2.54
# 6512                   3         0.00                        3       12.70
# 6518                   4         5.08                        0        2.54
# 6521                   0        -7.62                        0       -2.54
# 6525                  -1         2.54                        0        2.12
#
#       AvgSubAtt_diff  Red_Blue_Wins_diff  AvgTDPct_diff  AvgSigStrPct_diff  \
# 1             1.5000                  -2         -0.260              0.060
# 2             0.3000                  -3         -0.420              0.030
# 3             1.1000                   6          0.160              0.140
# 4             0.2000                   1          0.040             -0.070
# 5            -0.3000                  -8          0.020              0.010
# ...              ...                 ...            ...                ...
# 6508          1.2667                   8          0.184              0.083
# 6512          1.4444                   5          0.476              0.134
# 6518         -0.7000                  -3         -0.572             -0.010
# 6521         -0.6500                   3         -0.281              0.061
# 6525         -1.0000                   0         -1.000             -0.090
#
#       TDAvgLanded_diff  Red_Blue_curr_streak_diff  Red_Blue_Loss_diff  \
# 1               0.7200                         -2                   0
# 2               0.1300                         -3                  -2
# 3               2.9800                          1                   0
# 4               0.2500                          0                   0
# 5              -0.1100                          2                  -8
# ...                ...                        ...                 ...
# 6508            0.4667                         -2                   4
# 6512            1.3333                          0                   2
# 6518           -1.2000                          3                  -3
# 6521            2.1500                         -1                   3
# 6525           -1.0000                          0                   0
#
#       Age_diff
# 1            3
# 2           -2
# 3           -6
# 4            3
# 5           -2
# ...        ...
# 6508        -5
# 6512        -4
# 6518        -4
# 6521         0
# 6525         0
#
# [3511 rows x 12 columns]
