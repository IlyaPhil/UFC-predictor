# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ufc import get_fighter
from ufc import get_event

# %%
df_test = pd.DataFrame(get_event('UFC Fight Night: Dern vs. Ribas 2'))

# %%
df_test
# Out:
#                                  name        date                 location  \
# 0   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 1   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 2   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 3   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 4   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 5   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 6   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 7   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 8   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 9   UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# 10  UFC Fight Night: Дёрн vs. Рибас 2  2025-01-12  Las Vegas United States
# ...

# %%
df_test# Преобразовать словари в новые столбцы
df_test = df_test['fights'].apply(pd.Series)

# %%
df_test['red corner'].apply(pd.Series)
# Out:
#                     name   ranking  odds  \
# 0          Маккензи Дёрн         6  +164
# 1   Сантьяго Понзиниббио  Unranked  -135
# 2          Цезар Алмейда  Unranked  -258
# 3            Крис Кёртис  Unranked  +210
# 4      Кристиан Родригез  Unranked  +215
# 5       Пунахэле Сориано  Unranked  +170
# 6           Хосе Джонсон  Unranked  -185
# 7            Марко Тулио  Unranked  -500
# 8           Тиаго Мойзес  Unranked  -180
# 9        Престон Парсонс  Unranked  +410
# 10    Эрнеста Карескайте  Unranked  -258
# 11   Магомед Гаджиясулов  Unranked  -225
# 12          Фатима Клайн  Unranked  -800
# 13         Нурулло Алиев  Unranked  -650
#
#                                             link result
# 0          https://ufc.ru/athlete/makkenzi-dyorn    Win
# 1     https://ufc.ru/athlete/santyago-ponzinibio    Win
# 2           https://ufc.ru/athlete/cezar-almeyda    Win
# 3            https://ufc.ru/athlete/bobbi-grin-0   Loss
# 4           https://ufc.ru/athlete/ches-skelli-0    Win
# ...
